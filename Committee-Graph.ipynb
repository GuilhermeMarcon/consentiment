# %%
# !git clone https://github.com/GuilhermeMarcon/consentiment.git
# Out:
# Cloning into 'consentiment'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 37 (delta 8), reused 12 (delta 2), pack-reused 0
# Receiving objects: 100% (37/37), 934.69 KiB | 2.93 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 50.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %% [markdown]
# # Creating the embeddings

# %%
# possible by default: laptop14, rest14, hotel22
DATASET = 'hotel22'

MODEL = 'hotel22-bert-base-multilingual-cased-e2eabsa'

EMBEDDING_MODEL = 'bert-base-multilingual-cased'
# EMBEDDING_MODEL = 'bert-base-uncased'

ROOT = '/content/consentiment/data/'

# %%
import torch
from transformers import BertTokenizer, BertModel

# Load pre-trained model/tokenizer
tokenizer = BertTokenizer.from_pretrained(EMBEDDING_MODEL)
model = BertModel.from_pretrained(EMBEDDING_MODEL)

# Preprocess text
text = "This is an example sentence."
tokens = tokenizer.encode(text, add_special_tokens=True)

# Convert token IDs to PyTorch tensor
tokens_tensor = torch.tensor([tokens])

# Generate embeddings
with torch.no_grad():
    outputs = model(tokens_tensor)
    embedding = outputs.pooler_output.squeeze(0)
embedding
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# tensor([ 0.0118, -0.3553,  0.4665, -0.2460, -0.1493,  0.2987,  0.3957,  0.3839,
#         -0.3758,  0.3777, -0.1596, -0.3166, -0.3941, -0.2168,  0.3015, -0.1415,
#          0.7290,  0.2471,  0.2568, -0.1940, -0.9998, -0.3132, -0.1743, -0.3881,
#         -0.4211,  0.3379, -0.3137,  0.5097,  0.1776, -0.4438,  0.3100, -0.9998,
#          0.7531,  0.5151,  0.3102, -0.2703,  0.0209,  0.2605,  0.2450, -0.4463,
#         -0.3100,  0.0297, -0.3389,  0.1329, -0.1532, -0.5220, -0.2656,  0.1486,
#         -0.4792,  0.1321, -0.0032,  0.2347,  0.5217,  0.2278,  0.3569, -0.0136,
#          0.2426,  0.2342,  0.4652, -0.4817, -0.0228,  0.5353,  0.4132, -0.2530,
#         -0.1787, -0.1968,  0.3854, -0.0431,  0.5215, -0.1971, -0.3556, -0.3046,
#         -0.3084,  0.0566,  0.2902, -0.3672,  0.4513,  0.2999,  0.2436, -0.1398,
#         -0.4545, -0.4901, -0.4418,  0.3406, -0.3021,  0.5242,  0.4530, -0.4489,
#          0.3938, -0.2027,  0.2232,  0.4214, -0.3491,  0.4418, -0.2454, -0.3009,
#         -0.7882, -0.4126, -0.2740, -0.3540, -0.3437,  0.0786, -0.2959, -0.3705,
#         -0.3001, -0.4683,  0.3077,  0.1637, -0.1464,  0.4145,  0.1384, -0.3431,
#         -0.2921,  0.3902, -0.3652,  0.9424, -0.4642,  0.4680,  0.3447, -0.0808,
#         -0.4539,  0.9999,  0.2695, -0.3113,  0.2465,  0.3572, -0.6694,  0.3655,
#          0.3678,  0.5401,  0.2854, -0.2115, -0.2805, -0.1616, -0.6921, -0.2402,
#         -0.4296,  0.1715, -0.3451, -0.2972,  0.3304,  0.2739,  0.2119, -0.1565,
#          0.0297, -0.0905,  0.3415, -0.3729,  0.9999,  0.5256, -0.3417, -0.2325,
#          0.3819, -0.5290, -0.3955, -0.2422, -0.2139, -0.4737,  0.2592,  0.3765,
#          0.4277, -0.0718, -0.2424, -0.2495,  0.3957, -0.4671, -0.1540,  0.3725,
#          0.0202,  0.5038, -0.3653,  0.6067,  0.4044, -0.4988,  0.1720,  0.4872,
#          0.3649,  0.0372, -0.4226, -0.3026,  0.3880, -0.2557, -0.3516,  0.0326,
#         -0.2454, -0.4525,  0.1072, -0.1232, -0.0564,  0.3494, -0.5199,  0.3331,
#         -0.4000,  0.4227,  0.4201,  0.2669, -0.5409,  0.3614,  0.4907,  0.3272,
#          0.2536,  0.2690,  0.1986,  0.2771, -0.3600, -0.5043,  0.3831,  0.3816,
#          0.1721, -0.3980, -0.3822, -0.4397,  0.4979,  0.5613, -0.2678,  0.3779,
#          0.1693, -0.1674, -0.2785,  0.2197, -0.1378,  0.0659, -0.5566, -0.2661,
#         -0.2556,  0.3891,  0.2801,  0.3894,  0.4539, -0.2162, -0.3546, -0.3623,
#          0.2895, -0.0189, -0.2195,  0.7382, -0.1078,  0.2534, -0.3697, -0.2388,
#          0.3073, -0.0505,  0.5180,  0.9163,  0.3551, -0.3616,  0.0909,  0.1866,
#          0.2867, -0.3172,  0.2252, -0.3826,  0.6604,  0.3487,  0.3175, -0.9999,
#          0.3523,  0.2917,  0.2998,  0.1575,  0.3043,  0.3836,  0.2158,  0.7670,
#         -0.3001, -0.3382, -0.3854, -0.3554, -0.5035, -0.2092, -0.1835, -0.2651,
#         -0.3989, -0.1307, -0.2932,  0.2557,  0.4889, -0.9731,  0.7807,  0.3753,
#         -0.4639,  0.1441,  0.2452, -0.9999,  0.3898, -0.2248, -0.4418,  0.2819,
#         -0.1242, -0.2927,  0.3011,  0.2732,  0.3917,  0.2327, -0.1818,  0.5511,
#         -0.0772,  0.1850,  0.1923, -0.1271,  0.4976, -0.0897,  0.3156,  0.1683,
#         -0.1669,  0.4441, -0.2484,  0.3369,  0.3318,  0.1404,  0.1201, -0.3854,
#          0.5049, -0.6904,  0.4113, -0.0437, -0.2865, -0.0523,  0.0278, -0.3157,
#         -0.3302,  0.5823, -0.5356,  0.9998,  0.2677, -0.3404, -0.3889,  0.3143,
#          0.5601, -0.2615, -0.8055, -0.0426,  0.4285,  0.4351,  0.1253,  0.2896,
#          0.1903,  0.1868, -0.2944, -0.1839,  0.0765, -0.3105,  0.3210, -0.1808,
#         -0.6553,  0.2253, -0.2704, -0.1240, -0.6510,  0.3315,  0.2938,  0.3223,
#          0.2211,  0.0796, -0.3595,  0.5886,  0.3311, -0.3985, -0.2862, -0.3713,
#         -0.3947,  0.0998, -0.3815, -0.3283,  0.2624, -0.5520,  0.1634, -0.1646,
#         -0.1371, -0.3778,  0.4921, -0.9999, -0.1463,  0.4386, -0.2792,  0.4247,
#         -0.4294, -0.2309,  0.2771,  0.2231,  0.1888,  0.2261, -0.2292,  0.0870,
#         -0.2312,  0.2779,  0.6434,  0.4944,  0.2792, -0.4698,  0.1734, -0.3946,
#         -0.2597,  0.4334,  0.0817, -0.4006,  0.3450,  0.3754,  0.3916, -0.4373,
#          0.3652, -0.3279, -0.3485,  0.5417, -0.0387, -0.1513, -0.4335,  0.2851,
#         -0.3696,  0.5034,  0.2059,  0.3372, -0.0328,  0.3090, -0.4337, -0.2333,
#         -0.4434, -0.0216, -0.5250, -0.3960, -0.2834,  0.9998,  0.3485,  0.3296,
#         -0.3243,  0.3864,  0.2988, -0.4707,  0.2949,  0.4256,  0.3759, -0.2101,
#          0.3674,  0.4064,  0.3467,  0.3106,  0.1091,  0.2819, -0.3783,  0.5415,
#         -0.3573, -0.4305, -0.9756,  0.3977,  0.5049, -0.4680, -0.6955,  0.2749,
#         -0.5602,  0.3253, -0.2660,  0.1907,  0.3955, -0.1801,  0.2739, -0.2096,
#          0.9999,  0.0026,  0.3846,  0.4580,  0.2318, -0.3706, -0.4758, -0.2679,
#          0.3793, -0.3146,  0.2211, -0.8932,  0.3666,  0.1423,  0.5435, -0.4306,
#          0.3662, -0.5220,  0.5593, -0.2735, -0.1133, -0.4728,  0.2691, -0.5532,
#          0.4707, -0.3988,  0.2307, -0.3630,  0.3033, -0.1636,  0.4779, -0.4537,
#          0.3232, -0.3032, -0.0024, -0.4307,  0.1840, -0.5220,  0.9999, -0.1159,
#          0.4758, -0.2989,  0.3435, -0.3812,  0.5240,  0.6381, -0.2520,  0.2779,
#          0.3251, -0.6009,  0.3785, -0.3076, -0.8804, -0.1456,  0.9289,  0.5251,
#          0.3397,  0.4526,  0.2278,  0.2366, -0.3261,  0.2264,  0.7736,  0.2173,
#          0.3234,  0.4255,  0.2181, -0.3687, -0.3805,  0.9999,  0.9998,  0.2110,
#          0.3379, -0.2310, -0.3880, -0.3622,  0.3835,  0.2528,  0.4275, -0.0821,
#          0.2732, -0.4381, -0.1795,  0.0249, -0.2482, -0.1576,  0.0270, -0.3634,
#          0.6149,  0.3781,  0.3459,  0.5331,  0.2460,  0.3266, -0.1217, -0.4591,
#          0.4303, -0.5545, -0.0485, -0.2295,  0.1695, -0.9999, -0.5133, -0.3664,
#         -0.4950,  0.4847,  0.2125,  0.1158, -0.4505, -0.4487, -0.3901,  0.2492,
#          0.0939,  0.2101, -0.1542, -0.3445,  0.5226, -0.3241,  0.1684, -0.1653,
#         -0.5590, -0.5019, -0.2781, -0.3766,  0.4181, -0.2361, -0.3994,  0.4999,
#          0.2231,  0.1803, -0.3068,  0.4227, -0.0385,  0.2788,  0.2698,  0.1861,
#          0.2831, -0.6065, -0.4679, -0.3943, -0.3085, -0.4750,  0.3350, -0.3858,
#          0.2024, -0.1228,  0.1555, -0.4064,  0.1779,  0.3766,  0.4664, -0.3793,
#          0.3089,  0.5640, -0.3531,  0.4384,  0.1618, -0.1617, -0.4427,  0.9999,
#          0.0561,  0.2651,  0.2432, -0.1400,  0.1851,  0.4752,  0.4258,  0.0485,
#          0.8420, -0.2043,  0.3581,  0.2921,  0.3685,  0.1598,  0.1164,  0.0470,
#          0.5912,  0.3041,  0.3805,  0.5241,  0.3159,  0.5942,  0.2857,  0.1221,
#          0.5113,  0.3075,  0.0568,  0.2622, -0.2996, -0.2634, -0.3081, -0.2066,
#         -0.2444,  0.1460, -0.1289, -0.4809, -0.2546,  0.4576, -0.4356,  0.1435,
#         -0.4218, -0.2525,  0.3000, -0.3910,  0.4905, -0.0022,  0.3396, -0.6553,
#          0.2649, -0.1804, -0.4918, -0.1707, -0.4837,  0.3963,  0.2406, -0.1664,
#          0.4566, -0.2061,  0.4486,  0.0979, -0.3867,  0.1429, -0.9999,  0.3020,
#          0.3262, -0.2329,  0.2113,  0.2501,  0.4161,  0.3594, -0.3575, -0.3601,
#         -0.2242,  0.0205, -0.4854,  0.1054,  0.4904, -0.4129, -0.4134,  0.2947,
#         -0.4437,  0.3290,  0.2059, -0.3442,  0.2946, -0.3442,  0.2839, -0.4379,
#          0.2231, -0.4728, -0.3071,  0.3141, -0.4308, -0.3978, -0.1152,  0.3559,
#         -0.3758,  0.1676,  0.3741, -0.1556,  0.5132, -0.2208,  0.4497, -0.1047,
#          0.3954, -0.7584, -0.3589, -0.6118, -0.3255,  0.2237,  0.5712,  0.1253,
#          0.2636, -0.0099,  0.4068, -0.1693,  0.3647,  0.3912, -0.4514,  0.1922,
#         -0.4353,  0.3027, -0.3386,  0.1528, -0.9737, -0.3606,  0.2513,  0.5633,
#          0.4320, -0.4709, -0.2084, -0.3388, -0.1772,  0.2211, -0.0622,  0.4329,
#          0.1857,  0.3622, -0.1658, -0.0876,  0.7554, -0.3382,  0.1042,  0.4067,
#          0.3871,  0.8311,  0.4300,  0.3971,  0.1449, -0.3600,  0.4632,  0.4270])

# %%
import pandas as pd
import numpy as np
from ast import literal_eval

def read_df(filename, clean_empty=True):
    print("Reading", filename)
    df = pd.read_excel(filename)
    if(clean_empty): print("Original size", len(df))
    for col in df.columns[1:]:
        df[col] = df[col].apply(literal_eval)
        if(clean_empty): df = df[df[col].apply(len) != 0]
    print("Final size", len(df))
    return df

# %%
test = read_df(ROOT+DATASET+'/test.xlsx', clean_empty=False)
test = test.filter(regex=MODEL+'|review|annotation')
test = test[test.columns.drop(list(test.filter(regex='committee')))]
display(test.head())
# Out:
# Reading /content/consentiment/data/hotel22/test.xlsx
# Final size 84
#                                               review  \
# 0  Em abril de 2012 nos hospedamos no hotel refer...
# 1  EU fiquei uma semana neste hotel, é maravilhos...
# 2  Localização excelente, atendimento e serviços ...
# 3  Muito satisfeita com minha escolha de hospedag...
# 4  Estive hospedado no Mandarin Oriental NYC este...
#
#                                           annotation  \
# 0  [(lojas, POS), (hotel, POS), (quartos, POS), (...
# 1  [(rua, NEU), (café da manhã, POS), (localizaçã...
# 2  [(cama, NEU), (serviços, POS), (Café da manhã,...
# 3              [(localização, POS), (piscinas, POS)]
# 4  [(piscina, POS), (serviço, POS), (cama, POS), ...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-linear  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (antendimen...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(hotel, POS), (localização, POS), (quarto, PO...
# 4  [(banheira, POS), (serviço, POS), (piscina, POS)]
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-san  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(Hotel, POS), (hotel, POS), (Hotel, POS), (lo...
# 4  [(quarto, POS), (cama, POS), (banheira, POS), ...
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-tfm  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(hotel, POS), (localização, POS), (quarto, PO...
# 4  [(quarto, POS), (cama, POS), (banheira, POS), ...
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-crf  \
# 0  [(localizacao, POS), (lojas, POS), (Funcionari...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(Hotel, POS), (hotel, POS), (Hotel, POS), (lo...
# 4    [(quarto, POS), (serviço, POS), (piscina, POS)]
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-gru
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(Hotel, POS), (hotel, POS), (Hotel, POS), (lo...
# 4  [(quarto, POS), (banheira, NEU), (chuveiro, NE...

# %%
from tqdm import tqdm
tqdm.pandas()

def text_to_embedding(text):
    tokens = tokenizer.encode(text, add_special_tokens=True)
    tokens_tensor = torch.tensor([tokens])
    with torch.no_grad():
        outputs = model(tokens_tensor)
        embedding = outputs.pooler_output.squeeze(0).cpu().detach().numpy()
    return list(embedding)

def entities_to_embeddings(entities):
    return [text_to_embedding(x[0]) for x in entities]

def create_df_embeddings(df, text_col='review'):
    print("Embedding sentences...")
    original_cols = list(df.columns)
    # print(original_cols)
    df['text_emb'] = df[text_col].progress_apply(text_to_embedding)
    for col in original_cols[1:]:
        if col == 'annotation': continue
        if col.endswith('_emb'): continue
        print('Embedding entities "'+str(col)+'" ...')
        df[col+'_ents_emb'] = df[col].progress_apply(entities_to_embeddings)

create_df_embeddings(test, text_col='review')
# Out:
# Embedding sentences...
# 100%|██████████| 84/84 [00:35<00:00,  2.35it/s]
# Embedding entities "hotel22-bert-base-multilingual-cased-e2eabsa-linear" ...
# 100%|██████████| 84/84 [00:26<00:00,  3.18it/s]
# Embedding entities "hotel22-bert-base-multilingual-cased-e2eabsa-san" ...
# 100%|██████████| 84/84 [00:26<00:00,  3.14it/s]
# Embedding entities "hotel22-bert-base-multilingual-cased-e2eabsa-tfm" ...
# 100%|██████████| 84/84 [00:38<00:00,  2.17it/s]
# Embedding entities "hotel22-bert-base-multilingual-cased-e2eabsa-crf" ...
# 100%|██████████| 84/84 [00:31<00:00,  2.68it/s]
# Embedding entities "hotel22-bert-base-multilingual-cased-e2eabsa-gru" ...
# 100%|██████████| 84/84 [00:27<00:00,  3.05it/s]

# %%
# Saving to not create those embeddings again, just in case
test.to_pickle(ROOT+DATASET+'/test_embs.pkl')

# %%
import pandas as pd

test = pd.read_pickle(ROOT+DATASET+'/test_embs.pkl').rename(columns={'review':'text'})
test.head()
# Out:
#                                                 text  \
# 0  Em abril de 2012 nos hospedamos no hotel refer...
# 1  EU fiquei uma semana neste hotel, é maravilhos...
# 2  Localização excelente, atendimento e serviços ...
# 3  Muito satisfeita com minha escolha de hospedag...
# 4  Estive hospedado no Mandarin Oriental NYC este...
#
#                                           annotation  \
# 0  [(lojas, POS), (hotel, POS), (quartos, POS), (...
# 1  [(rua, NEU), (café da manhã, POS), (localizaçã...
# 2  [(cama, NEU), (serviços, POS), (Café da manhã,...
# 3              [(localização, POS), (piscinas, POS)]
# 4  [(piscina, POS), (serviço, POS), (cama, POS), ...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-linear  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (antendimen...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(hotel, POS), (localização, POS), (quarto, PO...
# 4  [(banheira, POS), (serviço, POS), (piscina, POS)]
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-san  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(Hotel, POS), (hotel, POS), (Hotel, POS), (lo...
# 4  [(quarto, POS), (cama, POS), (banheira, POS), ...
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-tfm  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(hotel, POS), (localização, POS), (quarto, PO...
# 4  [(quarto, POS), (cama, POS), (banheira, POS), ...
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-crf  \
# 0  [(localizacao, POS), (lojas, POS), (Funcionari...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(Hotel, POS), (hotel, POS), (Hotel, POS), (lo...
# 4    [(quarto, POS), (serviço, POS), (piscina, POS)]
#
#     hotel22-bert-base-multilingual-cased-e2eabsa-gru  \
# 0  [(hotel, POS), (localizacao, POS), (farmacia, ...
# 1  [(hotel, POS), (localização, POS), (hotel, POS...
# 2  [(Localização, POS), (atendimento, POS), (serv...
# 3  [(Hotel, POS), (hotel, POS), (Hotel, POS), (lo...
# 4  [(quarto, POS), (banheira, NEU), (chuveiro, NE...
#
#                                             text_emb  \
# 0  [0.18237072, -0.12672377, 0.20870394, -0.14584...
# 1  [0.036390137, 0.025100099, 0.11421439, 0.00126...
# 2  [0.1467385, -0.07306593, 0.21925724, -0.206326...
# 3  [0.17036031, -0.09626246, 0.20482376, -0.14230...
# 4  [0.22241282, -0.108299635, 0.25192547, -0.2934...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-linear_ents_emb  \
# 0  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 1  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 2  [[0.24602728, -0.18310703, 0.36531347, -0.1468...
# 3  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 4  [[0.20998994, -0.014243314, 0.2695733, -0.0812...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-san_ents_emb  \
# 0  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 1  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 2  [[0.24602728, -0.18310703, 0.36531347, -0.1468...
# 3  [[0.08619336, 0.018550532, 0.25463173, 0.07075...
# 4  [[0.34485826, 0.04855921, 0.1397063, 0.2155865...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-tfm_ents_emb  \
# 0  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 1  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 2  [[0.24602728, -0.18310703, 0.36531347, -0.1468...
# 3  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 4  [[0.34485826, 0.04855921, 0.1397063, 0.2155865...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-crf_ents_emb  \
# 0  [[0.14371605, -0.00707533, 0.17921875, -0.0401...
# 1  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 2  [[0.24602728, -0.18310703, 0.36531347, -0.1468...
# 3  [[0.08619336, 0.018550532, 0.25463173, 0.07075...
# 4  [[0.34485826, 0.04855921, 0.1397063, 0.2155865...
#
#   hotel22-bert-base-multilingual-cased-e2eabsa-gru_ents_emb
# 0  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 1  [[0.17371252, -0.1463264, 0.2799071, -0.189778...
# 2  [[0.24602728, -0.18310703, 0.36531347, -0.1468...
# 3  [[0.08619336, 0.018550532, 0.25463173, 0.07075...
# 4  [[0.34485826, 0.04855921, 0.1397063, 0.2155865...

# %% [markdown]
# # Graph Regularization

# %%
import networkx as nx
import numpy as np
from scipy.spatial import distance
from tqdm import tqdm

def create_graph_from_df(df, text='text', ignore_model=None, columns=2, embedding_mi=0.9, distance_threshold=0.1):
    G = nx.Graph()

    for col in df.columns[columns:]:
        if col == 'annotation': continue
        if col.endswith('_emb'): continue
        if ignore_model is not None:
            if type(ignore_model) is not list:
                ignore_model = [ignore_model]
            to_skip = False
            for igm in ignore_model:
                if igm in col:
                    print("Jumping", col)
                    to_skip = True
                    break
            if to_skip: continue

        print("Adding", col, "to graph.")

        for i, row in df.iterrows():
            annotation = np.asarray(df.iloc[i]['annotation'])
            if len(annotation) == 0: continue

            annotation_aspects = annotation[:, 0]
            for j, (aspect, sentiment) in enumerate(row[col]):
                node_id = f"{i}_{col}_{aspect}_{sentiment}"
                # print(node_id)
                aspect_embedding = embedding_mi * np.array(row[col+'_ents_emb'][j]) + (1.0-embedding_mi) * np.array(row[text+'_emb'])

                annotation_i = np.where(annotation_aspects == aspect)[0]
                # print(annotation_i)
                if len(annotation_i) >= 1:
                    annotation_sentiment = annotation[annotation_i, 1][0]
                else:
                    annotation_sentiment = 'NONE'
                    continue

                node_data = {
                    'text': row[text],
                    'model': col,
                    'aspect': aspect,
                    'sentiment': sentiment,
                    'annotation': annotation_sentiment,
                    'embedding': aspect_embedding
                }
                G.add_node(node_id, **node_data)


    for node1, data1 in tqdm(G.nodes(data=True)):
        for node2, data2 in G.nodes(data=True):
            # Linking same aspects with different sentiments
            if node1 != node2 and data1['aspect'].lower() == data2['aspect'].lower() and data1['sentiment'] != data2['sentiment']:
                weight = sum([a*b for a,b in zip(data1['embedding'], data2['embedding'])])
                G.add_edge(node1, node2, weight=weight)
            # Linking close embeddings with same sentiments
            elif node1 != node2 and data1['sentiment'] == data2['sentiment']:
                # dist = distance.cosine(data1['embedding'], data2['embedding'])
                dist = 1.0 - np.dot(data1['embedding'], data2['embedding']) / (np.linalg.norm(data1['embedding']) * np.linalg.norm(data2['embedding']))
                if dist < distance_threshold:
                    G.add_edge(node1, node2, weight=dist)
    return G

# %%
G = create_graph_from_df(test, embedding_mi=0.9, distance_threshold=0.1)
# Out:
# Adding hotel22-bert-base-multilingual-cased-e2eabsa-linear to graph.
# Adding hotel22-bert-base-multilingual-cased-e2eabsa-san to graph.
# Adding hotel22-bert-base-multilingual-cased-e2eabsa-tfm to graph.
# Adding hotel22-bert-base-multilingual-cased-e2eabsa-crf to graph.
# Adding hotel22-bert-base-multilingual-cased-e2eabsa-gru to graph.
# 100%|██████████| 1396/1396 [00:37<00:00, 37.36it/s]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
from tqdm.notebook import tqdm
import random

def regularization(G, num_labels=3, iterations=10, mi=0.1, save_plots=False, plot_max_depth=4, plot_max_nodes=20, plot_skip=0, plot_title='Graph Regularization'):

    nodes = []

    # inicializando vetor f para todos os nodes
    for node in G.nodes():
        if 'f' not in G.nodes[node]:
            G.nodes[node]['f'] = np.array([0.0]*num_labels)
            G.nodes[node]['y'] = np.array([0.0]*num_labels)
            if G.nodes[node]['sentiment']   == 'NEG':
                G.nodes[node]['y'][0] = 1.0
                G.nodes[node]['f'][0] = 1.0
            elif G.nodes[node]['sentiment'] == 'NEU':
                G.nodes[node]['y'][1] = 1.0
                G.nodes[node]['f'][1] = 1.0
            elif G.nodes[node]['sentiment'] == 'POS':
                G.nodes[node]['y'][2] = 1.0
                G.nodes[node]['f'][2] = 1.0
        nodes.append(node)

    pbar = tqdm(range(0, iterations))

    for iteration in pbar:
        random.shuffle(nodes)
        energy = 0.0

        for node in nodes:
            f_new = np.array([0.0]*num_labels)
            f_old = np.array(G.nodes[node]['f'])*1.0
            sum_w = 0.0

            for neighbor in G.neighbors(node):

                  w = 0.0
                  if 'weight' in G[node][neighbor]:
                      w = G[node][neighbor]['weight']

                  f_new += w*G.nodes[neighbor]['f']

                  sum_w += w

            if sum_w!=0.0:
              f_new /= sum_w
            else:
              f_new = f_old

            G.nodes[node]['f'] = f_new*1.0

            G.nodes[node]['f'] = G.nodes[node]['y'] * mi + G.nodes[node]['f']*(1.0-mi)

            energy += np.linalg.norm(f_new-f_old)

        iteration += 1

        message = 'Iteration '+str(iteration)+' | Energy = '+str(energy)
        # print(message)
        pbar.set_description(message)

    return G

def reset_regularization(G):
    for node in G.nodes():
        if 'f' not in G.nodes[node]: return
        break

    for node in G.nodes():
        G.nodes[node]['f'] = G.nodes[node]['y']
# reset_regularization(G)

# %%
regularization(G, mi=0.5, iterations=10)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# # Graph Committee

# %%
import numpy as np
import pandas as pd

isent_to_sent = {0:'NEG', 1:'NEU', 2:'POS'}

# graph, base dataframe
def graph_committee_to_data(G, bdf):
    df = bdf[['text', 'annotation']].copy()

    id_aspect_dict = [{} for _ in range(len(df))]

    for node in G.nodes():
        id, model, aspect, sentiment = node.split('_')
        id = int(id)

        if aspect not in id_aspect_dict[id]:
            id_aspect_dict[id][aspect] = []
        id_aspect_dict[id][aspect].append(G.nodes[node]['f'])

    data = []
    for id in range(len(df)):
        data.append([])
        for aspect in id_aspect_dict[id]:
            new_sent = isent_to_sent[np.argmax(np.mean(id_aspect_dict[id][aspect], axis=0))]
            data[-1].append((aspect, new_sent))
    return data

gdf = graph_committee_to_data(G, test)
gdf
# Out:
# [[('hotel', 'POS'),
#   ('limpeza', 'POS'),
#   ('quartos', 'POS'),
#   ('custo-benefício', 'POS'),
#   ('lojas', 'POS')],
#  [('hotel', 'POS'),
#   ('localização', 'POS'),
#   ('café da manhã', 'POS'),
#   ('rua', 'POS')],
#  [('Localização', 'POS'),
#   ('atendimento', 'POS'),
#   ('serviços', 'POS'),
#   ('hotel', 'POS'),
#   ('cama', 'POS'),
#   ('Café da manhã', 'POS')],
#  [('localização', 'POS'), ('piscinas', 'NEU')],
#  [('serviço', 'POS'), ('piscina', 'POS'), ('quarto', 'POS'), ('cama', 'POS')],
#  [('Hotel', 'POS'), ('quarto', 'POS'), ('internet', 'POS')],
#  [('quarto', 'POS'), ('preço', 'POS'), ('chuveiro', 'POS')],
#  [('hotel', 'POS'),
#   ('localização', 'NEG'),
#   ('elevador', 'NEG'),
#   ('estacionamento', 'NEG'),
#   ('quartos', 'NEG')],
#  [('quarto', 'POS'),
#   ('atendimento', 'POS'),
#   ('hotel', 'POS'),
#   ('internet', 'NEG')],
#  [('Hotel', 'POS'), ('quarto', 'POS'), ('chuveiro', 'POS')],
#  [('hotel', 'POS'),
#   ('quartos', 'POS'),
#   ('café da manhã', 'POS'),
#   ('funcionários', 'POS'),
#   ('localização', 'POS'),
#   ('internet', 'POS')],
#  [('cama', 'POS'), ('quarto', 'POS'), ('recepção', 'POS')],
#  [('hotel', 'POS'),
#   ('quarto', 'POS'),
#   ('café da manhã', 'POS'),
#   ('localização', 'POS')],
#  [('cidade', 'POS'), ('hotel', 'POS'), ('preço', 'POS'), ('museu', 'POS')],
#  [('hotel', 'POS')],
#  [('preço', 'POS'), ('hotel', 'POS'), ('banheira', 'POS'), ('quarto', 'POS')],
#  [('preço', 'POS'), ('serviço', 'POS'), ('Hotel', 'POS')],
#  [('hotel', 'POS'), ('quarto', 'POS')],
#  [('Hotel', 'NEG')],
#  [('hotel', 'POS'),
#   ('apartamento', 'POS'),
#   ('preço', 'POS'),
#   ('internet', 'NEG')],
#  [('quartos', 'POS')],
#  [('hotel', 'POS'), ('frigobar', 'NEG')],
#  [('Hotel', 'POS'),
#   ('preço', 'POS'),
#   ('serviços', 'NEU'),
#   ('café da manhã', 'POS'),
#   ('Toalhas', 'POS'),
#   ('elevador', 'NEU'),
#   ('serviço de quarto', 'POS'),
#   ('quartos', 'POS'),
#   ('frigobar', 'NEU')],
#  [('café da manhã', 'POS'), ('hotel', 'POS')],
#  [('Hotel', 'POS'),
#   ('serviço', 'POS'),
#   ('limpeza', 'POS'),
#   ('quartos', 'POS')],
#  [('hotel', 'NEU'),
#   ('aeroporto', 'NEU'),
#   ('Café da manhã', 'POS'),
#   ('atendimento', 'POS')],
#  [('hotel', 'POS'),
#   ('quartos', 'POS'),
#   ('localização', 'POS'),
#   ('preço', 'POS')],
#  [('quartos', 'NEG'),
#   ('casal', 'NEU'),
#   ('recepção', 'NEG'),
#   ('cidade', 'NEU')],
#  [('Internet', 'POS'), ('quarto', 'NEG')],
#  [('Hotel', 'POS'), ('instalações', 'POS'), ('cidade', 'POS')],
#  [('quarto', 'POS'),
#   ('camas', 'POS'),
#   ('café da manhã', 'POS'),
#   ('preço', 'NEG'),
#   ('localização', 'POS'),
#   ('hotel', 'POS'),
#   ('custo-benefício', 'POS')],
#  [('quartos', 'POS'), ('serviço', 'POS'), ('casal', 'NEU')],
#  [('quartos', 'POS'), ('café da manhã', 'POS'), ('lavanderia', 'NEG')],
#  [('hotel', 'POS'),
#   ('banheira', 'POS'),
#   ('Limpeza', 'POS'),
#   ('localização', 'POS'),
#   ('café da manhã', 'POS')],
#  [('hotel', 'POS'),
#   ('localização', 'POS'),
#   ('quarto', 'NEG'),
#   ('atendimento', 'POS')],
#  [('carpete', 'NEG')],
#  [('café da manhã', 'POS'),
#   ('quartos', 'POS'),
#   ('funcionários', 'POS'),
#   ('hotel', 'POS')],
#  [('hotel', 'POS'), ('quartos', 'POS')],
#  [('hotel', 'NEG'), ('corredores', 'NEG'), ('carpetes', 'NEG')],
#  [('hotel', 'POS'),
#   ('localização', 'POS'),
#   ('serviço', 'POS'),
#   ('funcionários', 'POS'),
#   ('quartos', 'POS')],
#  [('hotel', 'POS'),
#   ('café da manhã', 'POS'),
#   ('internet', 'POS'),
#   ('atendimento', 'POS')],
#  [('localização', 'POS'),
#   ('chuveiro', 'NEG'),
#   ('elevador', 'NEG'),
#   ('rua', 'POS'),
#   ('quarto', 'POS')],
#  [('hotel', 'NEG'), ('instalações', 'NEG'), ('limpeza', 'NEG')],
#  [('carpete', 'NEG'), ('teatro', 'NEU')],
#  [('localização', 'POS'), ('custo-benefício', 'POS')],
#  [('hotel', 'POS'), ('cidade', 'NEU'), ('quartos', 'POS')],
#  [('localização', 'POS'),
#   ('cama', 'POS'),
#   ('ducha', 'POS'),
#   ('limpeza', 'POS'),
#   ('café da manhã', 'POS')],
#  [('hotel', 'POS'), ('localização', 'POS'), ('quarto', 'POS')],
#  [('Hotel', 'POS'),
#   ('localização', 'POS'),
#   ('atendimento', 'POS'),
#   ('Shopping', 'POS')],
#  [('localização', 'POS'), ('hotel', 'POS'), ('aeroporto', 'NEU')],
#  [('Hotel', 'POS'),
#   ('camas', 'POS'),
#   ('chuveiro', 'POS'),
#   ('Café da manhã', 'POS'),
#   ('Internet', 'POS'),
#   ('funcionários', 'POS'),
#   ('Apartamentos', 'POS')],
#  [('hotel', 'POS')],
#  [('Quarto', 'POS'), ('Localização', 'POS'), ('preço', 'POS')],
#  [('Hotel', 'POS'), ('quarto', 'POS'), ('cama', 'POS'), ('piscina', 'POS')],
#  [('tv', 'NEG'),
#   ('hotel', 'POS'),
#   ('café da manhã', 'POS'),
#   ('preço', 'NEG'),
#   ('quarto', 'NEU'),
#   ('famílias', 'NEU'),
#   ('padrão', 'NEU')],
#  [('Quarto', 'POS'), ('cama', 'POS'), ('banheira', 'NEU'), ('cassino', 'POS')],
#  [('quartos', 'NEG'), ('shoppings', 'NEU'), ('aeroporto', 'NEU')],
#  [('recepção', 'POS'), ('café da manhã', 'NEG'), ('serviço de quarto', 'NEU')],
#  [('hotel', 'POS'),
#   ('Atendimento', 'POS'),
#   ('café da manhã', 'POS'),
#   ('Localização', 'POS'),
#   ('quarto', 'POS')],
#  [('Hotel', 'POS'), ('quartos', 'POS'), ('camas', 'POS')],
#  [('hotel', 'POS'),
#   ('cidade', 'NEU'),
#   ('atendimento', 'POS'),
#   ('café da manhã', 'POS'),
#   ('quarto', 'POS')],
#  [('Hotel', 'POS'),
#   ('quartos', 'POS'),
#   ('café da manhã', 'POS'),
#   ('localização', 'POS'),
#   ('roupa de cama', 'POS')],
#  [('localização', 'POS'), ('aeroporto', 'NEU'), ('hotel', 'POS')],
#  [('hotel', 'POS'), ('quarto', 'NEG')],
#  [('hotel', 'POS'), ('localização', 'POS')],
#  [('hotel', 'POS'), ('ruas', 'NEU'), ('frigobar', 'NEG')],
#  [('Hotel', 'POS'),
#   ('localização', 'POS'),
#   ('Café da manhã', 'POS'),
#   ('Quarto', 'POS')],
#  [('hotel', 'POS'), ('Funcionários', 'POS'), ('Quartos', 'POS')],
#  [('estacionamento', 'POS')],
#  [('preço', 'POS'), ('Internet', 'POS'), ('recepção', 'POS')],
#  [('piscina', 'POS'), ('hotel', 'POS')],
#  [('Estacionamento', 'NEG')],
#  [('localização', 'POS'),
#   ('cama', 'POS'),
#   ('funcionários', 'POS'),
#   ('ruas', 'POS')],
#  [('localização', 'POS'),
#   ('hotel', 'POS'),
#   ('shopping', 'POS'),
#   ('funcionários', 'POS'),
#   ('quarto', 'POS'),
#   ('chuveiro', 'POS'),
#   ('banheira', 'POS'),
#   ('pia', 'POS')],
#  [('hotel', 'POS'), ('café da manhã', 'POS'), ('quarto', 'POS')],
#  [('cidade', 'NEU'),
#   ('shopping', 'NEU'),
#   ('lojas', 'NEU'),
#   ('atendimento', 'POS'),
#   ('hotel', 'NEG'),
#   ('elevador', 'NEG')],
#  [('hotel', 'POS'), ('atendimento', 'POS'), ('localização', 'POS')],
#  [('hotel', 'POS'), ('jantar', 'POS')],
#  [('carpete', 'NEG')],
#  [('hotel', 'POS'), ('atendimento', 'POS'), ('cozinha', 'POS')],
#  [('hotel', 'POS'), ('quarto', 'POS'), ('frigobar', 'NEU')],
#  [('localização', 'POS')],
#  [('localização', 'POS'),
#   ('cidade', 'NEU'),
#   ('funcionários', 'POS'),
#   ('corredor', 'NEU'),
#   ('quartos', 'NEU'),
#   ('internet', 'NEG')],
#  [('hotel', 'POS'),
#   ('rua', 'POS'),
#   ('funcionários', 'POS'),
#   ('localização', 'POS'),
#   ('custo-benefício', 'POS'),
#   ('café da manhã', 'NEG')]]

# %%
test = pd.read_excel(ROOT+DATASET+'/test.xlsx')
test[MODEL+'-committee-graph'] = gdf
test.to_excel(ROOT+DATASET+'/test.xlsx', index=False)
test
# Out:
#                                                review  \
# 0   Em abril de 2012 nos hospedamos no hotel refer...
# 1   EU fiquei uma semana neste hotel, é maravilhos...
# 2   Localização excelente, atendimento e serviços ...
# 3   Muito satisfeita com minha escolha de hospedag...
# 4   Estive hospedado no Mandarin Oriental NYC este...
# ..                                                ...
# 79  The Benjamim hotel possui bom atendimento, qua...
# 80  Me hospedei nesse hotel em março de 2012, pega...
# 81  É um hotel com uma excelente localização. Em f...
# 82  Primeiro ponto: A localização é muito boa, fac...
# 83  Escolhi este hotel em função das dicas que out...
#
#                                            annotation  \
# 0   [('lojas', 'POS'), ('hotel', 'POS'), ('quartos...
# 1   [('rua', 'NEU'), ('café da manhã', 'POS'), ('l...
# 2   [('cama', 'NEU'), ('serviços', 'POS'), ('Café ...
# 3       [('localização', 'POS'), ('piscinas', 'POS')]
# 4   [('piscina', 'POS'), ('serviço', 'POS'), ('cam...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('frigobar', 'NEG'), ('quarto', 'POS'), ('hot...
# 81        [('localização', 'POS'), ('almoço', 'POS')]
# 82  [('quartos', 'NEU'), ('localização', 'POS'), (...
# 83  [('café da manhã', 'NEG'), ('hotel', 'POS'), (...
#
#    hotel22-bert-base-multilingual-cased-e2eabsa-linear  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('a...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hotel', 'POS'), ('localização', 'POS'), ('q...
# 4   [('banheira', 'POS'), ('serviço', 'POS'), ('pi...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('c...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('Quarto...
# 81         [('hotel', 'POS'), ('localização', 'POS')]
# 82  [('localização', 'POS'), ('cidade', 'NEU'), ('...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#      hotel22-bert-base-multilingual-cased-e2eabsa-san  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('h...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('Hotel', 'POS'), ('hotel', 'POS'), ('Hotel',...
# 4   [('quarto', 'POS'), ('cama', 'POS'), ('banheir...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('h...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('Quarto...
# 81  [('hotel', 'POS'), ('localização', 'POS'), ('H...
# 82  [('localização', 'POS'), ('cidade', 'NEU'), ('...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#      hotel22-bert-base-multilingual-cased-e2eabsa-tfm  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('h...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hotel', 'POS'), ('localização', 'POS'), ('q...
# 4   [('quarto', 'POS'), ('cama', 'POS'), ('banheir...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('h...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('Quarto...
# 81  [('hotel', 'POS'), ('localização', 'POS'), ('H...
# 82  [('localização', 'POS'), ('cidade', 'NEU'), ('...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#      hotel22-bert-base-multilingual-cased-e2eabsa-crf  \
# 0   [('localizacao', 'POS'), ('lojas', 'POS'), ('F...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('h...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('Hotel', 'POS'), ('hotel', 'POS'), ('Hotel',...
# 4   [('quarto', 'POS'), ('serviço', 'POS'), ('pisc...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('h...
# 80  [('hotel', 'NEU'), ('quarto', 'POS'), ('Quarto...
# 81  [('hotel', 'POS'), ('localização', 'POS'), ('H...
# 82  [('localização', 'POS'), ('cidade', 'NEU'), ('...
# 83  [('hotel', 'POS'), ('quarto', 'POS'), ('rua', ...
#
#      hotel22-bert-base-multilingual-cased-e2eabsa-gru  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('h...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('Hotel', 'POS'), ('hotel', 'POS'), ('Hotel',...
# 4   [('quarto', 'POS'), ('banheira', 'NEU'), ('chu...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('h...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('Quarto...
# 81  [('hotel', 'POS'), ('localização', 'POS'), ('H...
# 82  [('localização', 'POS'), ('cidade', 'NEU'), ('...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#    hotel22-bert-base-multilingual-cased-e2eabsa-committee-voting  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('a...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hotel', 'POS'), ('localização', 'POS'), ('q...
# 4   [('banheira', 'POS'), ('serviço', 'POS'), ('pi...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('c...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('Quarto...
# 81  [('hotel', 'POS'), ('localização', 'POS'), ('H...
# 82  [('localização', 'POS'), ('cidade', 'NEU'), ('...
# 83  [('hotel', 'POS'), ('quarto', 'POS'), ('rua', ...
#
#    hotel22-bert-base-multilingual-cased-e2eabsa-committee-graph  \
# 0   [(hotel, POS), (limpeza, POS), (quartos, POS),...
# 1   [(hotel, POS), (localização, POS), (café da ma...
# 2   [(Localização, POS), (atendimento, POS), (serv...
# 3               [(localização, POS), (piscinas, NEU)]
# 4   [(serviço, POS), (piscina, POS), (quarto, POS)...
# ..                                                ...
# 79  [(hotel, POS), (atendimento, POS), (cozinha, P...
# 80     [(hotel, POS), (quarto, POS), (frigobar, NEU)]
# 81                               [(localização, POS)]
# 82  [(localização, POS), (cidade, NEU), (funcionár...
# 83  [(hotel, POS), (rua, POS), (funcionários, POS)...
#
#    rest14-bert-base-multilingual-cased-e2eabsa-linear  ...  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...  ...
# 1   [('localização', 'POS'), ('louvre', 'POS'), ('...  ...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...  ...
# 3   [('hospedagem', 'POS'), ('arquitetura', 'POS')...  ...
# 4   [('quarto', 'POS'), ('cama king', 'POS'), ('so...  ...
# ..                                                ...  ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...  ...
# 80  [('quarto', 'POS'), ('quarto', 'NEU'), ('frigo...  ...
# 81  [('localização', 'POS'), ('paragem', 'POS'), (...  ...
# 82  [('localização', 'POS'), ('funcionários', 'POS...  ...
# 83  [('quarto', 'POS'), ('banheiro', 'POS'), ('rua...  ...
#
#    multidomain-bert-base-multilingual-cased-e2eabsa-san  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('localização', 'POS'), ('louvre', 'POS'), ('...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('arquitetura', 'POS')...
# 4   [('quarto', 'POS'), ('cama king', 'POS'), ('so...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('quarto', 'POS'), ('vista', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('quartos', 'POS'), (...
# 82  [('localização', 'POS'), ('estrutura', 'POS'),...
# 83  [('quarto', 'POS'), ('banheiro', 'POS'), ('rua...
#
#    multidomain-bert-base-multilingual-cased-e2eabsa-tfm  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('localização', 'POS'), ('louvre', 'POS'), ('...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('arquitetura', 'POS')...
# 4   [('quarto', 'POS'), ('cama king', 'POS'), ('so...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80                                 [('vista', 'POS')]
# 81  [('localização', 'POS'), ('paragem', 'POS'), (...
# 82  [('localização', 'POS'), ('receptividade', 'NE...
# 83  [('quarto', 'POS'), ('banheiro', 'POS'), ('rua...
#
#    multidomain-bert-base-multilingual-cased-e2eabsa-crf  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('localização', 'POS'), ('louvre', 'POS'), ('...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('arquitetura', 'POS')...
# 4   [('quarto', 'POS'), ('cama king', 'POS'), ('so...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('quarto', 'POS'), ('vista', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('paragem', 'POS'), (...
# 82  [('localização', 'POS'), ('funcionários', 'POS...
# 83  [('quarto', 'POS'), ('banheiro', 'POS'), ('rua...
#
#    multidomain-bert-base-multilingual-cased-e2eabsa-gru  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('localização', 'POS'), ('antendimento', 'POS...
# 2   [('Localização', 'POS'), ('quarto', 'POS'), ('...
# 3   [('localização', 'POS'), ('quarto', 'POS'), ('...
# 4   [('quarto', 'POS'), ('cama king', 'POS'), ('so...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('quarto', 'POS'), ('vista', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('quartos', 'POS'), (...
# 82  [('localização', 'POS'), ('funcionários', 'NEG...
# 83  [('quarto', 'POS'), ('banheiro', 'POS'), ('rua...
#
#                                                gpt3.5  \
# 0   [('localizacao', 'POS'), ('metro', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('a...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('Hotel Aria', 'POS'),...
# 4   [('quarto', 'POS'), ('vista', 'POS'), ('locali...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('vista', 'POS'), ('limpeza', 'POS'), ('decor...
# 81  [('localização', 'POS'), ('quartos', 'NEG'), (...
# 82  [('localização', 'POS'), ('receptividade dos f...
# 83  [('hotel', 'POS'), ('quarto', 'POS'), ('banhei...
#
#    gpt3.5-bert-base-multilingual-cased-e2eabsa-linear  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('l...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('Hotel Aria', 'POS'),...
# 4   [('quarto', 'POS'), ('sofá', 'POS'), ('mesa de...
# ..                                                ...
# 79  [('hotel', 'POS'), ('atendimento', 'POS'), ('q...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('paragem de autocarr...
# 82  [('localização', 'POS'), ('receptividade', 'PO...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#       gpt3.5-bert-base-multilingual-cased-e2eabsa-san  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('l...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('escolha de hospedagem', 'POS'), ('Hotel Ari...
# 4   [('quarto', 'POS'), ('cama', 'POS'), ('sofá', ...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('paragem de autocarr...
# 82  [('localização', 'POS'), ('receptividade', 'PO...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#       gpt3.5-bert-base-multilingual-cased-e2eabsa-tfm  \
# 0   [('hotel', 'POS'), ('localizacao', 'POS'), ('f...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('c...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('hotel', 'POS'), ('Ho...
# 4   [('quarto', 'POS'), ('sofá', 'POS'), ('mesa de...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('paragem de autocarr...
# 82  [('localização', 'POS'), ('receptividade', 'PO...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#       gpt3.5-bert-base-multilingual-cased-e2eabsa-crf  \
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('m...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('Hotel Aria', 'POS'),...
# 4   [('quarto', 'POS'), ('cama', 'POS'), ('sofá', ...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('paragem de autocarr...
# 82  [('localização', 'POS'), ('receptividade', 'PO...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
#       gpt3.5-bert-base-multilingual-cased-e2eabsa-gru
# 0   [('localizacao', 'POS'), ('farmacia', 'POS'), ...
# 1   [('hotel', 'POS'), ('localização', 'POS'), ('l...
# 2   [('Localização', 'POS'), ('atendimento', 'POS'...
# 3   [('hospedagem', 'POS'), ('Hotel Aria', 'POS'),...
# 4   [('quarto', 'POS'), ('cama', 'POS'), ('sofá', ...
# ..                                                ...
# 79  [('atendimento', 'POS'), ('quarto', 'POS'), ('...
# 80  [('hotel', 'POS'), ('quarto', 'POS'), ('vista'...
# 81  [('localização', 'POS'), ('paragem de autocarr...
# 82  [('localização', 'POS'), ('receptividade', 'PO...
# 83  [('hotel', 'POS'), ('hotel', 'POS'), ('quarto'...
#
# [84 rows x 31 columns]
